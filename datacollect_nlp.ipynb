# %%
pip install stackapi
# Out:
# Collecting stackapi
#   Downloading StackAPI-0.3.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from stackapi) (2.32.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from stackapi) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->stackapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->stackapi) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->stackapi) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->stackapi) (2024.6.2)
# Downloading StackAPI-0.3.1-py3-none-any.whl (7.2 kB)
# Installing collected packages: stackapi
# Successfully installed stackapi-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from stackapi import StackAPI
import pandas as pd
from datetime import datetime
import calendar
import time

# %%
API_KEYS = [
    'rl_aLCzCCSQbfYe8u564o3ZjHCbQ',
    'rl_A2PxPHTZyZXSGdpgXD1BdCVgS',
    'rl_XZH4h9xu9QcJ2N95h9M1Jn125'
]

TAGS = ['nlp', 'bert', 'tokenisation', 'language model', 'summarization', 'text classification', 'spacy', 'nltk', 'sentiment analysis', 'stemming', 'lemmatization', 'natural language processing']
BATCH_SIZE = 30
PAGE_SIZE = 100
MAX_POSTS = 30000  # Slightly above 30k to ensure full coverage
START_YEAR = 2008
END_YEAR = 2025

# %%
key_index = 0
posts = []
seen_ids = set()

# %%
def get_site():
    return StackAPI('stackoverflow', key=API_KEYS[key_index], page_size=PAGE_SIZE)

SITE = get_site()

def switch_key():
    global key_index, SITE
    key_index = (key_index + 1) % len(API_KEYS)
    print(f"\n Switching to key ending in: {API_KEYS[key_index][-5:]}")
    SITE = get_site()

def collect_questions_for_year(tag, year):
    global SITE
    fromdate = calendar.timegm(datetime(year, 1, 1).utctimetuple())
    todate = calendar.timegm(datetime(year, 12, 31).utctimetuple())
    page = 1

    while True:
        if len(posts) >= MAX_POSTS:
            break
        try:
            print(f"[{tag}] Year: {year} | Page: {page} | Key: {API_KEYS[key_index][-5:]}")
            questions = SITE.fetch(
                'questions',
                tagged=tag,
                fromdate=fromdate,
                todate=todate,
                filter='withbody',
                page=page
            )

            for item in questions.get('items', []):
                qid = item.get('question_id')
                if qid not in seen_ids:
                    seen_ids.add(qid)
                    posts.append({
                        'post_id': qid,
                        'title': item.get('title', ''),
                        'description': item.get('body', ''),
                        'tags': ', '.join(item.get('tags', [])),
                        'accepted_answer_id': item.get('accepted_answer_id'),
                        'creation_date': pd.to_datetime(item.get('creation_date', 0), unit='s'),
                        'view_count': item.get('view_count', 0),
                        'tag_matched': tag  # <-- New column to store which tag matched
                })

            if not questions.get('has_more', False):
                break
            page += 1
            time.sleep(0.5)

        except Exception as e:
            print(f" Error on page {page}, year {year}: {e}")
            switch_key()
            time.sleep(3)
            continue
    print(f"Collected {len(seen_ids)} unique posts so far.")

# %%
for year in range(START_YEAR, END_YEAR + 1):
    for tag in TAGS:
        collect_questions_for_year(tag, year)
    if len(posts) >= MAX_POSTS:
        break

df = pd.DataFrame(posts)
print(f"\n Total RAW posts collected: {len(df)}")
# Out:
# [nlp] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 44 unique posts so far.
# [bert] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 44 unique posts so far.
# [tokenisation] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 44 unique posts so far.
# [language model] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 44 unique posts so far.
# [summarization] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 44 unique posts so far.
# [text classification] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 44 unique posts so far.
# [spacy] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 44 unique posts so far.
# [nltk] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 46 unique posts so far.
# [sentiment analysis] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 46 unique posts so far.
# [stemming] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 48 unique posts so far.
# [lemmatization] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 48 unique posts so far.
# [natural language processing] Year: 2008 | Page: 1 | Key: jHCbQ
# Collected 48 unique posts so far.
# [nlp] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 208 unique posts so far.
# [bert] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 208 unique posts so far.
# [tokenisation] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 208 unique posts so far.
# [language model] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 208 unique posts so far.
# [summarization] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 210 unique posts so far.
# [text classification] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 210 unique posts so far.
# [spacy] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 210 unique posts so far.
# [nltk] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 215 unique posts so far.
# [sentiment analysis] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 215 unique posts so far.
# [stemming] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 221 unique posts so far.
# [lemmatization] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 223 unique posts so far.
# [natural language processing] Year: 2009 | Page: 1 | Key: jHCbQ
# Collected 223 unique posts so far.
# [nlp] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 322 unique posts so far.
# [bert] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 322 unique posts so far.
# [tokenisation] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 322 unique posts so far.
# [language model] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 322 unique posts so far.
# [summarization] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 325 unique posts so far.
# [text classification] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 325 unique posts so far.
# [spacy] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 325 unique posts so far.
# [nltk] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 371 unique posts so far.
# [sentiment analysis] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 371 unique posts so far.
# [stemming] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 381 unique posts so far.
# [lemmatization] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 382 unique posts so far.
# [natural language processing] Year: 2010 | Page: 1 | Key: jHCbQ
# Collected 382 unique posts so far.
# [nlp] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 482 unique posts so far.
# [bert] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 482 unique posts so far.
# [tokenisation] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 482 unique posts so far.
# [language model] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 482 unique posts so far.
# [summarization] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 490 unique posts so far.
# [text classification] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 490 unique posts so far.
# [spacy] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 490 unique posts so far.
# [nltk] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 640 unique posts so far.
# [sentiment analysis] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 640 unique posts so far.
# [stemming] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 674 unique posts so far.
# [lemmatization] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 677 unique posts so far.
# [natural language processing] Year: 2011 | Page: 1 | Key: jHCbQ
# Collected 677 unique posts so far.
# [nlp] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 977 unique posts so far.
# [bert] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 977 unique posts so far.
# [tokenisation] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 977 unique posts so far.
# [language model] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 977 unique posts so far.
# [summarization] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 982 unique posts so far.
# [text classification] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 982 unique posts so far.
# [spacy] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 982 unique posts so far.
# [nltk] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 1172 unique posts so far.
# [sentiment analysis] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 1172 unique posts so far.
# [stemming] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 1209 unique posts so far.
# [lemmatization] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 1212 unique posts so far.
# [natural language processing] Year: 2012 | Page: 1 | Key: jHCbQ
# Collected 1212 unique posts so far.
# [nlp] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1312 unique posts so far.
# [bert] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1312 unique posts so far.
# [tokenisation] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1312 unique posts so far.
# [language model] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1312 unique posts so far.
# [summarization] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1333 unique posts so far.
# [text classification] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1333 unique posts so far.
# [spacy] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1333 unique posts so far.
# [nltk] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1715 unique posts so far.
# [sentiment analysis] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1715 unique posts so far.
# [stemming] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1746 unique posts so far.
# [lemmatization] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1750 unique posts so far.
# [natural language processing] Year: 2013 | Page: 1 | Key: jHCbQ
# Collected 1750 unique posts so far.
# [nlp] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 1850 unique posts so far.
# [bert] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 1850 unique posts so far.
# [tokenisation] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 1850 unique posts so far.
# [language model] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 1850 unique posts so far.
# [summarization] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 1889 unique posts so far.
# [text classification] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 1889 unique posts so far.
# [spacy] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 1889 unique posts so far.
# [nltk] Year: 2014 | Page: 1 | Key: jHCbQ
# [nltk] Year: 2014 | Page: 2 | Key: jHCbQ
# Collected 2411 unique posts so far.
# [sentiment analysis] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 2411 unique posts so far.
# [stemming] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 2467 unique posts so far.
# [lemmatization] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 2477 unique posts so far.
# [natural language processing] Year: 2014 | Page: 1 | Key: jHCbQ
# Collected 2477 unique posts so far.
# [nlp] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 2776 unique posts so far.
# [bert] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 2776 unique posts so far.
# [tokenisation] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 2776 unique posts so far.
# [language model] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 2776 unique posts so far.
# [summarization] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 2798 unique posts so far.
# [text classification] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 2798 unique posts so far.
# [spacy] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 2800 unique posts so far.
# [nltk] Year: 2015 | Page: 1 | Key: jHCbQ
# [nltk] Year: 2015 | Page: 2 | Key: jHCbQ
# [nltk] Year: 2015 | Page: 3 | Key: jHCbQ
# Collected 3432 unique posts so far.
# [sentiment analysis] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 3432 unique posts so far.
# [stemming] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 3478 unique posts so far.
# [lemmatization] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 3490 unique posts so far.
# [natural language processing] Year: 2015 | Page: 1 | Key: jHCbQ
# Collected 3490 unique posts so far.
# [nlp] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 3889 unique posts so far.
# [bert] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 3889 unique posts so far.
# [tokenisation] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 3889 unique posts so far.
# [language model] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 3889 unique posts so far.
# [summarization] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 3920 unique posts so far.
# [text classification] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 3920 unique posts so far.
# [spacy] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 3966 unique posts so far.
# [nltk] Year: 2016 | Page: 1 | Key: jHCbQ
# [nltk] Year: 2016 | Page: 2 | Key: jHCbQ
# [nltk] Year: 2016 | Page: 3 | Key: jHCbQ
# [nltk] Year: 2016 | Page: 4 | Key: jHCbQ
# [nltk] Year: 2016 | Page: 5 | Key: jHCbQ
# Collected 4762 unique posts so far.
# [sentiment analysis] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 4762 unique posts so far.
# [stemming] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 4795 unique posts so far.
# [lemmatization] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 4807 unique posts so far.
# [natural language processing] Year: 2016 | Page: 1 | Key: jHCbQ
# Collected 4807 unique posts so far.
# [nlp] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 5006 unique posts so far.
# [bert] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 5006 unique posts so far.
# [tokenisation] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 5006 unique posts so far.
# [language model] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 5006 unique posts so far.
# [summarization] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 5040 unique posts so far.
# [text classification] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 5040 unique posts so far.
# [spacy] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 5251 unique posts so far.
# [nltk] Year: 2017 | Page: 1 | Key: jHCbQ
# [nltk] Year: 2017 | Page: 2 | Key: jHCbQ
# [nltk] Year: 2017 | Page: 3 | Key: jHCbQ
# [nltk] Year: 2017 | Page: 4 | Key: jHCbQ
# [nltk] Year: 2017 | Page: 5 | Key: jHCbQ
# [nltk] Year: 2017 | Page: 6 | Key: jHCbQ
# Collected 6107 unique posts so far.
# [sentiment analysis] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 6107 unique posts so far.
# [stemming] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 6142 unique posts so far.
# [lemmatization] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 6160 unique posts so far.
# [natural language processing] Year: 2017 | Page: 1 | Key: jHCbQ
# Collected 6160 unique posts so far.
# [nlp] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 6260 unique posts so far.
# [bert] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 6260 unique posts so far.
# [tokenisation] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 6260 unique posts so far.
# [language model] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 6260 unique posts so far.
# [summarization] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 6295 unique posts so far.
# [text classification] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 6295 unique posts so far.
# [spacy] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 6745 unique posts so far.
# [nltk] Year: 2018 | Page: 1 | Key: jHCbQ
# [nltk] Year: 2018 | Page: 2 | Key: jHCbQ
# [nltk] Year: 2018 | Page: 3 | Key: jHCbQ
# [nltk] Year: 2018 | Page: 4 | Key: jHCbQ
# [nltk] Year: 2018 | Page: 5 | Key: jHCbQ
# Collected 7542 unique posts so far.
# [sentiment analysis] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 7542 unique posts so far.
# [stemming] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 7564 unique posts so far.
# [lemmatization] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 7582 unique posts so far.
# [natural language processing] Year: 2018 | Page: 1 | Key: jHCbQ
# Collected 7582 unique posts so far.
# [nlp] Year: 2019 | Page: 1 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 2 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 3 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 4 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 5 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 6 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 7 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 8 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 9 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 10 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 11 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 12 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 13 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 14 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 15 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 16 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 17 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 18 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 19 | Key: jHCbQ
# [nlp] Year: 2019 | Page: 20 | Key: jHCbQ
# Collected 9925 unique posts so far.
# [bert] Year: 2019 | Page: 1 | Key: jHCbQ
# Collected 9959 unique posts so far.
# [tokenisation] Year: 2019 | Page: 1 | Key: jHCbQ
# Collected 9959 unique posts so far.
# [language model] Year: 2019 | Page: 1 | Key: jHCbQ
# Collected 9959 unique posts so far.
# [summarization] Year: 2019 | Page: 1 | Key: jHCbQ
# Collected 9977 unique posts so far.
# [text classification] Year: 2019 | Page: 1 | Key: jHCbQ
# Collected 9977 unique posts so far.
# [spacy] Year: 2019 | Page: 1 | Key: jHCbQ
# [spacy] Year: 2019 | Page: 2 | Key: jHCbQ
# [spacy] Year: 2019 | Page: 3 | Key: jHCbQ
# [spacy] Year: 2019 | Page: 4 | Key: jHCbQ
# Collected 10365 unique posts so far.
# [nltk] Year: 2019 | Page: 1 | Key: jHCbQ
# [nltk] Year: 2019 | Page: 2 | Key: jHCbQ
# [nltk] Year: 2019 | Page: 3 | Key: jHCbQ
# Collected 10804 unique posts so far.
# [sentiment analysis] Year: 2019 | Page: 1 | Key: jHCbQ
# Collected 10804 unique posts so far.
# [stemming] Year: 2019 | Page: 1 | Key: jHCbQ
# Collected 10829 unique posts so far.
# [lemmatization] Year: 2019 | Page: 1 | Key: jHCbQ
# Collected 10845 unique posts so far.
# [natural language processing] Year: 2019 | Page: 1 | Key: jHCbQ
# Collected 10845 unique posts so far.
# [nlp] Year: 2020 | Page: 1 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 2 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 3 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 4 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 5 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 6 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 7 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 8 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 9 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 10 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 11 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 12 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 13 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 14 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 15 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 16 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 17 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 18 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 19 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 20 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 21 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 22 | Key: jHCbQ
# [nlp] Year: 2020 | Page: 23 | Key: jHCbQ
# Collected 13482 unique posts so far.
# [bert] Year: 2020 | Page: 1 | Key: jHCbQ
# Collected 13752 unique posts so far.
# [tokenisation] Year: 2020 | Page: 1 | Key: jHCbQ
# Collected 13752 unique posts so far.
# [language model] Year: 2020 | Page: 1 | Key: jHCbQ
# Collected 13752 unique posts so far.
# [summarization] Year: 2020 | Page: 1 | Key: jHCbQ
# Collected 13771 unique posts so far.
# [text classification] Year: 2020 | Page: 1 | Key: jHCbQ
# Collected 13771 unique posts so far.
# [spacy] Year: 2020 | Page: 1 | Key: jHCbQ
# [spacy] Year: 2020 | Page: 2 | Key: jHCbQ
# [spacy] Year: 2020 | Page: 3 | Key: jHCbQ
# [spacy] Year: 2020 | Page: 4 | Key: jHCbQ
# Collected 14150 unique posts so far.
# [nltk] Year: 2020 | Page: 1 | Key: jHCbQ
# [nltk] Year: 2020 | Page: 2 | Key: jHCbQ
# [nltk] Year: 2020 | Page: 3 | Key: jHCbQ
# Collected 14579 unique posts so far.
# [sentiment analysis] Year: 2020 | Page: 1 | Key: jHCbQ
# Collected 14579 unique posts so far.
# [stemming] Year: 2020 | Page: 1 | Key: jHCbQ
# Collected 14598 unique posts so far.
# [lemmatization] Year: 2020 | Page: 1 | Key: jHCbQ
# Collected 14610 unique posts so far.
# [natural language processing] Year: 2020 | Page: 1 | Key: jHCbQ
# Collected 14610 unique posts so far.
# [nlp] Year: 2021 | Page: 1 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 2 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 3 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 4 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 5 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 6 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 7 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 8 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 9 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 10 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 11 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 12 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 13 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 14 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 15 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 16 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 17 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 18 | Key: jHCbQ
# [nlp] Year: 2021 | Page: 19 | Key: jHCbQ
# Collected 16841 unique posts so far.
# [bert] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17135 unique posts so far.
# [tokenisation] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17135 unique posts so far.
# [language model] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17135 unique posts so far.
# [summarization] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17157 unique posts so far.
# [text classification] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17157 unique posts so far.
# [spacy] Year: 2021 | Page: 1 | Key: jHCbQ
# [spacy] Year: 2021 | Page: 2 | Key: jHCbQ
# [spacy] Year: 2021 | Page: 3 | Key: jHCbQ
# Collected 17528 unique posts so far.
# [nltk] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17799 unique posts so far.
# [sentiment analysis] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17799 unique posts so far.
# [stemming] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17816 unique posts so far.
# [lemmatization] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17822 unique posts so far.
# [natural language processing] Year: 2021 | Page: 1 | Key: jHCbQ
# Collected 17822 unique posts so far.
# [nlp] Year: 2022 | Page: 1 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 2 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 3 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 4 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 5 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 6 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 7 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 8 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 9 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 10 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 11 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 12 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 13 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 14 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 15 | Key: jHCbQ
# [nlp] Year: 2022 | Page: 16 | Key: jHCbQ
# Collected 19766 unique posts so far.
# [bert] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20017 unique posts so far.
# [tokenisation] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20017 unique posts so far.
# [language model] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20017 unique posts so far.
# [summarization] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20030 unique posts so far.
# [text classification] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20030 unique posts so far.
# [spacy] Year: 2022 | Page: 1 | Key: jHCbQ
# [spacy] Year: 2022 | Page: 2 | Key: jHCbQ
# Collected 20307 unique posts so far.
# [nltk] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20488 unique posts so far.
# [sentiment analysis] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20488 unique posts so far.
# [stemming] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20496 unique posts so far.
# [lemmatization] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20504 unique posts so far.
# [natural language processing] Year: 2022 | Page: 1 | Key: jHCbQ
# Collected 20504 unique posts so far.
# [nlp] Year: 2023 | Page: 1 | Key: jHCbQ
# [nlp] Year: 2023 | Page: 2 | Key: jHCbQ
# [nlp] Year: 2023 | Page: 3 | Key: jHCbQ
# [nlp] Year: 2023 | Page: 4 | Key: jHCbQ
# [nlp] Year: 2023 | Page: 5 | Key: jHCbQ
# [nlp] Year: 2023 | Page: 6 | Key: jHCbQ
# [nlp] Year: 2023 | Page: 7 | Key: jHCbQ
# [nlp] Year: 2023 | Page: 8 | Key: jHCbQ
# [nlp] Year: 2023 | Page: 9 | Key: jHCbQ
# Collected 21757 unique posts so far.
# [bert] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 21896 unique posts so far.
# [tokenisation] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 21896 unique posts so far.
# [language model] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 21896 unique posts so far.
# [summarization] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 21914 unique posts so far.
# [text classification] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 21914 unique posts so far.
# [spacy] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 22046 unique posts so far.
# [nltk] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 22124 unique posts so far.
# [sentiment analysis] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 22124 unique posts so far.
# [stemming] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 22129 unique posts so far.
# [lemmatization] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 22131 unique posts so far.
# [natural language processing] Year: 2023 | Page: 1 | Key: jHCbQ
# Collected 22131 unique posts so far.
# [nlp] Year: 2024 | Page: 1 | Key: jHCbQ
# [nlp] Year: 2024 | Page: 2 | Key: jHCbQ
# [nlp] Year: 2024 | Page: 3 | Key: jHCbQ
# Collected 22799 unique posts so far.
# [bert] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22888 unique posts so far.
# [tokenisation] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22888 unique posts so far.
# [language model] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22888 unique posts so far.
# [summarization] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22893 unique posts so far.
# [text classification] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22893 unique posts so far.
# [spacy] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22962 unique posts so far.
# [nltk] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22990 unique posts so far.
# [sentiment analysis] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22990 unique posts so far.
# [stemming] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22995 unique posts so far.
# [lemmatization] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22996 unique posts so far.
# [natural language processing] Year: 2024 | Page: 1 | Key: jHCbQ
# Collected 22996 unique posts so far.
# [nlp] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23070 unique posts so far.
# [bert] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23074 unique posts so far.
# [tokenisation] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23074 unique posts so far.
# [language model] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23074 unique posts so far.
# [summarization] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23075 unique posts so far.
# [text classification] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23075 unique posts so far.
# [spacy] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23082 unique posts so far.
# [nltk] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23089 unique posts so far.
# [sentiment analysis] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23089 unique posts so far.
# [stemming] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23089 unique posts so far.
# [lemmatization] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23089 unique posts so far.
# [natural language processing] Year: 2025 | Page: 1 | Key: jHCbQ
# Collected 23089 unique posts so far.
#
#  Total RAW posts collected: 23089

# %%
df.to_csv('stackoverflow_raw_posts.csv', index=False)
print(f"\n Saved ALL {len(df)} RAW posts to 'stackoverflow_raw_posts.csv'")
# Out:
#  Saved ALL 23089 RAW posts to 'stackoverflow_raw_posts.csv'

# %%
def fetch_accepted_answers(df):
    SITE_ANS = StackAPI('stackoverflow', key=API_KEYS[-1])
    answer_bodies = {}
    accepted_ids = df['accepted_answer_id'].dropna().astype(int).unique().tolist()
    print(f" Fetching {len(accepted_ids)} accepted answers in batches...")

    for i in range(0, len(accepted_ids), BATCH_SIZE):
        batch = accepted_ids[i:i + BATCH_SIZE]
        try:
            result = SITE_ANS.fetch('answers/{ids}', ids=batch, filter='withbody')
            for item in result.get('items', []):
                answer_bodies[item['answer_id']] = item.get('body', '')
        except Exception as e:
            print(f" Batch fetch error: {e}")
            time.sleep(5)
        time.sleep(0.5)

    return answer_bodies

accepted_answers = fetch_accepted_answers(df)

# CORRECT MERGE: Add answers WITHOUT REMOVING ANY ROW
df['accepted_answer'] = df['accepted_answer_id'].map(accepted_answers).fillna('')
df.drop(columns='accepted_answer_id', inplace=True)

# SAVE FINAL CSV CLEARLY
df.to_csv('stackoverflow_nlp_with_answers.csv', index=False)
print(f" Saved {len(df)} posts (with or without answers) to 'stackoverflow_nlp_with_answers.csv'")
# Out:
#  Fetching 9517 accepted answers in batches...
#  Saved 23089 posts (with or without answers) to 'stackoverflow_nlp_with_answers.csv'
